# %% [markdown]
# <a href="https://colab.research.google.com/github/meriem-belkacemi/SIC/blob/master/ML_association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # First dataset

# %%
dataset = [
            ['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
            ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
            ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
            ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
            ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']
          ]

df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#             0         1         2      3      4      5     6
# 0       Skirt  Sneakers     Scarf  Pants    Hat   None  None
# 1  Sunglasses     Skirt  Sneakers  Pants    Hat   None  None
# 2       Dress   Sandals     Scarf  Pants  Heels   None  None
# 3       Dress  Necklace  Earrings  Scarf    Hat  Heels   Hat
# 4    Earrings     Skirt     Skirt  Scarf  Shirt  Pants  None

# %%
counts = df.apply(pd.Series.value_counts).fillna(0).apply(np.sum, axis = 1).sort_values(ascending=False)
lab = list(counts.index)
val = list(counts.values)
label_index_org = np.array(lab)
label_values_org = np.array(val)

plt.figure(figsize=(10,7))
plt.bar(label_index_org,label_values_org, color = 'red')
plt.xlabel('Items')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.title('Frequency of apperence', fontsize=20)
plt.show()

# %%
a=TransactionEncoder()
a2=a.fit(dataset).transform(dataset)    
df=pd.DataFrame(a2, columns=a.columns_)

# %%
frequent_items = apriori(df, min_support=0.5, use_colnames=True)
frequent_items
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_items ,metric="confidence",min_threshold=0.2) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  ...    lift  leverage  conviction
# 0     (Pants)     (Scarf)                 0.8  ...  0.9375     -0.04         0.8
# 1     (Scarf)     (Pants)                 0.8  ...  0.9375     -0.04         0.8
# 2     (Pants)     (Skirt)                 0.8  ...  1.2500      0.12         1.6
# 3     (Skirt)     (Pants)                 0.6  ...  1.2500      0.12         inf
#
# [4 rows x 9 columns]

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_items,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  ...  lift  leverage  conviction
# 0     (Skirt)     (Pants)                 0.6  ...  1.25      0.12         inf
#
# [1 rows x 9 columns]

# %% [markdown]
# # The big dataset

# %%
df = pd.read_csv("/content/Market_Basket_Optimisation.csv", header=None)

# %%
df.head()
# Out:
#               0          1           2   ...               17       18         19
# 0         shrimp    almonds     avocado  ...  frozen smoothie  spinach  olive oil
# 1        burgers  meatballs        eggs  ...              NaN      NaN        NaN
# 2        chutney        NaN         NaN  ...              NaN      NaN        NaN
# 3         turkey    avocado         NaN  ...              NaN      NaN        NaN
# 4  mineral water       milk  energy bar  ...              NaN      NaN        NaN
#
# [5 rows x 20 columns]

# %%
counts = df.apply(pd.Series.value_counts).fillna(0).apply(np.sum, axis = 1).sort_values(ascending=False)
lab = list(counts.index)
val = list(counts.values)
label_index_org = np.array(lab)
label_values_org = np.array(val)

plt.figure(figsize=(10,7))
plt.bar(label_index_org,label_values_org, color = 'red')
plt.xlabel('Items')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.title('Frequency of apperence', fontsize=20)
plt.show()

# %%
data = df.to_numpy().tolist()

for idx, line in enumerate(data):
  data[idx] = [product for product in line if not pd.isnull(product)]

# %%
import mlxtend
from mlxtend.preprocessing import TransactionEncoder

te=TransactionEncoder()
te_ary=te.fit(data).transform(data)    
df=pd.DataFrame(te_ary, columns=te.columns_)

# %%
df.head()
# Out:
#     asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0       False     True               True  ...   True        False     False
# 1       False    False              False  ...  False        False     False
# 2       False    False              False  ...  False        False     False
# 3       False    False              False  ...  False        False     False
# 4       False    False              False  ...  False        False     False
#
# [5 rows x 120 columns]

# %%
from mlxtend.frequent_patterns import apriori
frequent_items = apriori(df, min_support=0.05, use_colnames=True)
frequent_items
# Out:
#      support                    itemsets
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 2   0.059992                   (chicken)
# 3   0.163845                 (chocolate)
# 4   0.080389                   (cookies)
# 5   0.051060               (cooking oil)
# 6   0.179709                      (eggs)
# 7   0.079323                  (escalope)
# 8   0.170911              (french fries)
# 9   0.063325           (frozen smoothie)
# 10  0.095321         (frozen vegetables)
# 11  0.052393             (grated cheese)
# 12  0.132116                 (green tea)
# 13  0.098254               (ground beef)
# 14  0.076523            (low fat yogurt)
# 15  0.129583                      (milk)
# 16  0.238368             (mineral water)
# 17  0.065858                 (olive oil)
# 18  0.095054                  (pancakes)
# 19  0.071457                    (shrimp)
# 20  0.050527                      (soup)
# 21  0.174110                 (spaghetti)
# ...

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_items ,metric="confidence",min_threshold=0.2) # associate itemsets with confidence over 70%.
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0  (mineral water)      (chocolate)  ...  0.013604    1.073256
# 1      (chocolate)  (mineral water)  ...  0.013604    1.122357
# 2  (mineral water)           (eggs)  ...  0.008090    1.043158
# 3           (eggs)  (mineral water)  ...  0.008090    1.062815
# 4  (mineral water)      (spaghetti)  ...  0.018223    1.102008
# 5      (spaghetti)  (mineral water)  ...  0.018223    1.159314
#
# [6 rows x 9 columns]

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_items,metric="lift",min_threshold=1.25)
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0  (mineral water)      (chocolate)  ...  0.013604    1.073256
# 1      (chocolate)  (mineral water)  ...  0.013604    1.122357
# 2  (mineral water)      (spaghetti)  ...  0.018223    1.102008
# 3      (spaghetti)  (mineral water)  ...  0.018223    1.159314
#
# [4 rows x 9 columns]
